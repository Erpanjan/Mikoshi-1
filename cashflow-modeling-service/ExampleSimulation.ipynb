# %% [markdown]
# # Financial Simulation
# The goal of this notebook is to estimate finances in retirement based on inputs
# such as contribution percentages to various account types, investment growth,
# required minimum distributions, etc.
#
# The inputs are listed first and projections are performed at the end. Review each
# section and update as needed as.

# %%
# %%capture
# Check if life_model is already installed, otherwise install required packages
import importlib.util
if importlib.util.find_spec('life_model') is None:
    # !python -m pip install mesa pandas matplotlib life_model

# %%
from life_model.model import LifeModel

model = LifeModel(start_year=2023)

# %% [markdown]
# ## People
# This section captures information about the people being studied.

# %%
from life_model.people.family import Family
from life_model.people.person import Person, Spending

family = Family(model)

john = Person(
    family = family,
    name = 'John',
    age = 44,
    retirement_age = 60,
    spending = Spending(
        model = model,
        base = 12000,
        yearly_increase = 5
    )
)

jane = Person(
    family = family,
    name = 'Jane',
    age = 45,
    retirement_age = 60,
    spending = Spending(
        model = model,
        base = 12000,
        yearly_increase = 5
    )
)

family
# Out:
# <b>Family:</b><ul><li>John<ul><li>Age: 44</li><li>Retirement Age: 60</li><li>Debt: 0</li></ul></li><li>Jane<ul><li>Age: 45</li><li>Retirement Age: 60</li><li>Debt: 0</li></ul></li></ul>

# %% [markdown]
# ## Bank Accounts
# Bank accounts associated with each person. These earn a small amount of interest, which may be compounded at different rates, however the rates are much lower than other types of accounts.

# %%
from life_model.account.bank import BankAccount

BankAccount(
    owner = john,
    company = 'Bank',
    type = 'Checking',
    balance = 20000,
    interest_rate = 0.5
)
BankAccount(
    owner = jane,
    company = 'Credit Union',
    type = 'Checking',
    balance = 30000,
    interest_rate = 0.01
)
BankAccount(
    owner = jane,
    company = 'Credit Union',
    type = 'Savings',
    balance = 20100,
    interest_rate = 0.1
)

family
# Out:
# <b>Family:</b><ul><li>John<ul><li>Age: 44</li><li>Retirement Age: 60</li><li>Checking account at Bank balance: $20,000</li><li>Debt: 0</li></ul></li><li>Jane<ul><li>Age: 45</li><li>Retirement Age: 60</li><li>Checking account at Credit Union balance: $30,000</li><li>Savings account at Credit Union balance: $20,100</li><li>Debt: 0</li></ul></li></ul>

# %% [markdown]
# ## Jobs
# This section captures information about people's jobs.

# %%
from life_model.work.job import Job, Salary

pizza_papa = Job(
    owner = john,
    company = 'Pizza Papa',
    role = 'Manager',
    salary = Salary(
        model = model,
        base = 50000,
        yearly_increase = 1, # Percent
        yearly_bonus = 1 # Percent
    )
)

bargain_ben = Job(
    owner = jane,
    company = 'Bargain Ben',
    role = 'Manager',
    salary = Salary(
        model = model,
        base = 65000,
        yearly_increase = 3, # Percent
        yearly_bonus = 2 # Percent
    )
)

family
# Out:
# <b>Family:</b><ul><li>John<ul><li>Age: 44</li><li>Retirement Age: 60</li><li>Manager at Pizza Papa</li><li>Checking account at Bank balance: $20,000</li><li>Debt: 0</li></ul></li><li>Jane<ul><li>Age: 45</li><li>Retirement Age: 60</li><li>Manager at Bargain Ben</li><li>Checking account at Credit Union balance: $30,000</li><li>Savings account at Credit Union balance: $20,100</li><li>Debt: 0</li></ul></li></ul>

# %% [markdown]
# ## 401k Accounts
# Retirement accounts set up by a company, usually offering some sort of match

# %%
from life_model.account.job401k import Job401kAccount

john_401k = Job401kAccount(
    job = pizza_papa,
    pretax_balance = 100000,
    pretax_contrib_percent = 15,
    roth_balance = 100000,
    roth_contrib_percent = 5,
    average_growth = 5, # Percent
    company_match_percent = 50
)

jane_401k = Job401kAccount(
    job = bargain_ben,
    pretax_balance = 50000,
    pretax_contrib_percent = 15,
    average_growth = 5, # Percent
    company_match_percent = 0
)

# %% [markdown]
# ## Housing
# This section captures housing details.

# %%
from life_model.housing.home import Home, Mortgage, HomeExpenses

home = Home(
    person = john,
    name = "John and Jane's House",
    purchase_price = 350000,
    value_yearly_increase = 5,
    down_payment = 100000,
    mortgage = Mortgage(
        loan_amount = 275000,
        start_date = 2019,
        length_years = 30,
        yearly_interest_rate = 3.5,
        principal = 235324,
        monthly_payment = 1819,
    ),
    expenses = HomeExpenses(
        model = model,
        property_tax_percent = 0.88,
        home_insurance_percent = 0.5,
        maintenance_amount = 700,
        maintenance_increase = 2,
        improvement_amount = 700,
        improvement_increase = 2,
        hoa_amount = 1800,
        hoa_increase = 2
    )
)
home
# Out:
# John and Jane&#x27;s House, purchase price $350,000, monthly mortgage $1,819

# %% [markdown]
# ## Life Events
# Expected life events happening at a certain time

# %%
from life_model.lifeevents import LifeEvents, LifeEvent

LifeEvents(model, [
    LifeEvent(john.get_year_at_age(50), "John and Jane get married", john.get_married, jane),
    LifeEvent(john.get_year_at_age(55), "John buys a new car for $32k", john.spending.add_expense, 32000)
])
# Out:
# <table><tr><th>Year:</th><th>Event:</th></tr>
# <tr><td>2029</td><td>John and Jane get married</td></tr>
# <tr><td>2034</td><td>John buys a new car for $32k</td></tr>
# </table>

# %% [markdown]
# ## Social Security
# This section captures details about social security benefits
#
# Note: Income history can be found at: https://www.ssa.gov/prepare/review-record-earnings

# %%
from life_model.insurance.social_security import SocialSecurity

john_ss = SocialSecurity(
    person = john,
    withdrawal_start_age = 67,
    income_history = [
        (2003, 8000),  (2004, 14000), (2005, 16000), (2006, 17000),
        (2007, 20000), (2008, 27000), (2009, 28000), (2010, 30000),
        (2011, 33000), (2012, 37000), (2013, 39000), (2014, 40000),
        (2015, 45000), (2016, 45000), (2017, 46000), (2018, 46000),
        (2019, 47000), (2020, 47000), (2021, 48000), (2022, 49000),
        (2023, 50000), (2024, 52000), (2025, 54000),
    ]
)

jane_ss = SocialSecurity(
    person = jane,
    withdrawal_start_age = 67,
    income_history = [
        (2000, 20000), (2001, 21000), (2002, 23000), (2003, 23000),
        (2004, 24000), (2005, 24000), (2006, 25000), (2007, 27000),
        (2008, 29000), (2009, 29000), (2010, 32000), (2011, 32000),
        (2012, 33000), (2013, 33000), (2014, 40000), (2015, 41000),
        (2016, 45000), (2017, 45000), (2018, 46000), (2019, 46000),
        (2020, 46000), (2021, 60000), (2022, 63000), (2023, 65000),
        (2024, 67000), (2025, 70000),
    ]
)

# %% [markdown]
# ## Life Insurance
# This section captures life insurance policies for financial protection and investment.

# %%
from life_model.insurance.life_insurance import LifeInsurance, LifeInsuranceType

# Term life insurance for John - cheaper premiums, no cash value
john_term_life = LifeInsurance(
    person=john,
    policy_type=LifeInsuranceType.TERM,
    death_benefit=750000,  # 15x annual salary for family protection
    monthly_premium=65,    # Typical term life rate
    term_years=20          # 20-year term
)

# Whole life insurance for Jane - higher premiums but builds cash value
jane_whole_life = LifeInsurance(
    person=jane,
    policy_type=LifeInsuranceType.WHOLE,
    death_benefit=500000,     # 10x annual salary
    monthly_premium=280,      # Higher premium for whole life
    cash_value_growth_rate=3.5,  # Conservative growth rate
    loan_interest_rate=5.0,   # Interest on policy loans
    premium_increase_rate=0   # Fixed premiums
)

print("Life Insurance Policies Created:")
print(f"John's Term Life: ${john_term_life.death_benefit:,} benefit, ${john_term_life.monthly_premium}/month")
print(f"Jane's Whole Life: ${jane_whole_life.death_benefit:,} benefit, ${jane_whole_life.monthly_premium}/month")

# Example: Taking a loan against Jane's whole life policy (after building cash value)
# This would typically be done during the simulation when cash value has accumulated
# jane_whole_life.cash_value = 15000  # Simulated accumulated cash value
# loan_amount = jane_whole_life.take_loan(10000)
# print(f"Jane took a ${loan_amount:,.0f} loan against her life insurance policy")
# Out:
# Life Insurance Policies Created:
# John's Term Life: $750,000 benefit, $65/month
# Jane's Whole Life: $500,000 benefit, $280/month

# %% [markdown]
# ## Simulation
# Perform the model over the defined time frame.

# %%
model.end_year = john.get_year_at_age(90)
model.add_agent_stat('Age', 'age')
model.run()
model.event_log
# Out:
# <table><tr><th>Year:</th><th>Event:</th></tr>
# <tr><td>2023</td><td>John's term life premium increased 180% ($65 -> $182/month) due to age</td></tr>
# <tr><td>2029</td><td>John and Jane got married at age 51 and 52</td></tr>
# <tr><td>2036</td><td>Jane reached retirement age (age 59.5)</td></tr>
# <tr><td>2037</td><td>John reached retirement age (age 59.5)</td></tr>
# <tr><td>2037</td><td>Jane retired from Bargain Ben</td></tr>
# <tr><td>2038</td><td>John retired from Pizza Papa</td></tr>
# <tr><td>2041</td><td>John's life insurance policy lapsed due to non-payment</td></tr>
# </table>

# %%
# Get all of John and Jane's data
df = model.datacollector.get_agent_vars_dataframe()
df = df.xs(john.unique_id, level='AgentID').join(
    df.xs(jane.unique_id, level='AgentID'),
    lsuffix=' John',
    rsuffix=' Jane'
)

# Only show the columns we care about
df = df[['Age John', 'Age Jane']]
df = df.join(model.datacollector.get_model_vars_dataframe())
df = df.drop(df.index[0]) # Drop the first row, which is the initial state

model.format_dataframe(df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9897d">
#   <thead>
#     <tr>
#       <th id="T_9897d_level0_col0" class="col_heading level0 col0" >Age John</th>
#       <th id="T_9897d_level0_col1" class="col_heading level0 col1" >Age Jane</th>
#       <th id="T_9897d_level0_col2" class="col_heading level0 col2" >Year</th>
#       <th id="T_9897d_level0_col3" class="col_heading level0 col3" >Income</th>
#       <th id="T_9897d_level0_col4" class="col_heading level0 col4" >Bank Balance</th>
#       <th id="T_9897d_level0_col5" class="col_heading level0 col5" >401k Balance</th>
#       <th id="T_9897d_level0_col6" class="col_heading level0 col6" >Useable Balance</th>
#       <th id="T_9897d_level0_col7" class="col_heading level0 col7" >Debt</th>
#       <th id="T_9897d_level0_col8" class="col_heading level0 col8" >Taxes</th>
#       <th id="T_9897d_level0_col9" class="col_heading level0 col9" >Spending</th>
# ...

# %%
model.format_dataframe(model.aggregate_dataframe(df))
# Out:
# <style type="text/css">
# </style>
# <table id="T_edec7">
#   <thead>
#     <tr>
#       <th id="T_edec7_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_edec7_level0_col1" class="col_heading level0 col1" >Income</th>
#       <th id="T_edec7_level0_col2" class="col_heading level0 col2" >Bank Balance</th>
#       <th id="T_edec7_level0_col3" class="col_heading level0 col3" >401k Balance</th>
#       <th id="T_edec7_level0_col4" class="col_heading level0 col4" >Useable Balance</th>
#       <th id="T_edec7_level0_col5" class="col_heading level0 col5" >Debt</th>
#       <th id="T_edec7_level0_col6" class="col_heading level0 col6" >Taxes</th>
#       <th id="T_edec7_level0_col7" class="col_heading level0 col7" >Spending</th>
#       <th id="T_edec7_level0_col8" class="col_heading level0 col8" >401k Contrib</th>
#       <th id="T_edec7_level0_col9" class="col_heading level0 col9" >401k Match</th>
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

agent_df = model.datacollector.get_agent_vars_dataframe()

df = pd.DataFrame()
df["John's 401k"] = agent_df.xs(john_401k.unique_id, level='AgentID')["401k Balance"]
df["Jane's 401k"] = agent_df.xs(jane_401k.unique_id, level='AgentID')["401k Balance"]

ax = df.plot(subplots=False, legend=True)
ax.set_title('401k Balances')
ax.set_ylabel('Balance')
ax.set_xlabel('Years')
y_fmt = StrMethodFormatter('${x:1,.0f}')
ax.yaxis.set_major_formatter(y_fmt)
plt.legend(loc='best')
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(model.simulated_years, home.mortgage.stat_principal_payment_history, label="Amt to Principal")
ax.bar(model.simulated_years, home.mortgage.stat_interest_payment_history, bottom=home.mortgage.stat_principal_payment_history, label="Amt to Interest")

ax.set_title('Yearly Mortgage Payments')
ax.set_ylabel('Yearly Payment')
ax.set_xlabel('Years')
y_fmt = StrMethodFormatter('${x:1,.0f}')
ax.yaxis.set_major_formatter(y_fmt)
ax.legend()
plt.show()
